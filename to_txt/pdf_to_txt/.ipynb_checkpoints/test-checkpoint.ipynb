# %%
from PdfConversion import *
import os

# %%
root_dir = '../../../../../data/00_nh_poc/11_legal_advice_hwp_128/hwp/'

# %%
for file in os.listdir(root_dir):
    if not file.endswith('.pdf'):
        continue
    else:
        file_path = os.path.join(root_dir, file)
        print(file_path)
        a = PdfConversion(file_path)
        print(a.pdf_to_txt())
        break
# Out:
# ../../../../../data/00_nh_poc/11_legal_advice_hwp_128/hwp/(117.1)첨부자료[업무연락] NH농협카드-한국조폐공사 MOU관련 NDA법무검토요청.pdf
# {'/Author': '농협', '/Creator': 'Hancom PDF 1.3.0.519', '/Producer': 'Hancom PDF 1.3.0.519', '/CreationDate': "D:20200518102744+09'00'", '/ModDate': "D:20200518102744+09'00'", '/PDFVersion': '1.4'}
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# asdf
